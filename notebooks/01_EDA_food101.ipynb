# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

# %%
import matplotlib.pyplot as plt
import tensorflow_datasets as tfds
import numpy as np
from src.preprocessing.preprocessing import load_and_split_data, TARGET_CLASSES, IMG_SIZE, NUM_CLASSES
# Out:
# WARNING:tensorflow:From C:\Users\socik\Documents\food-recognition\.venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
train_ds, val_ds, test_ds, ds_info = load_and_split_data(batch_size=32)

# %%
image_batch, label_batch = next(iter(train_ds))
plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(3, 3, i + 1)
    plt.imshow(image_batch[i]) 
    label_index = label_batch[i].numpy()
    plt.title(f"Klasa: {TARGET_CLASSES[label_index]}") 
    plt.axis("off")

plt.suptitle(f"Przykład przetworzonych obrazów ({IMG_SIZE}x{IMG_SIZE})")
plt.show()
