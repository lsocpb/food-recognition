# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

# %%
import tensorflow as tf
tf.config.list_physical_devices('GPU')
print(tf.__version__)
print(tf.test.is_gpu_available(), tf.config.list_physical_devices('GPU'))
# Out:
# WARNING:tensorflow:From D:\Repos\food-recognition\.venv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# 2.15.0
# WARNING:tensorflow:From C:\Users\krzys\AppData\Local\Temp\ipykernel_37992\2443837570.py:4: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# False []

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print(tf.version.VERSION)
print(tf.sysconfig.get_build_info()['cuda_version'])
# Out:
# Num GPUs Available:  0
# 2.15.0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 4
#       2 print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
#       3 print(tf.version.VERSION)
# ----> 4 print(tf.sysconfig.get_build_info()['cuda_version'])
#
# KeyError: 'cuda_version'
